# %%
# !pip install apache-beam[interactive]
# Out:
# Requirement already satisfied: apache-beam[interactive] in /usr/local/lib/python3.12/dist-packages (2.69.0)
# Requirement already satisfied: crcmod<2.0,>=1.7 in /usr/local/lib/python3.12/dist-packages (from apache-beam[interactive]) (1.7)
# Requirement already satisfied: cryptography<48.0.0,>=39.0.0 in /usr/local/lib/python3.12/dist-packages (from apache-beam[interactive]) (43.0.3)
# Requirement already satisfied: orjson<4,>=3.9.7 in /usr/local/lib/python3.12/dist-packages (from apache-beam[interactive]) (3.11.4)
# Requirement already satisfied: fastavro<2,>=0.23.6 in /usr/local/lib/python3.12/dist-packages (from apache-beam[interactive]) (1.12.1)
# Requirement already satisfied: fasteners<1.0,>=0.3 in /usr/local/lib/python3.12/dist-packages (from apache-beam[interactive]) (0.20)
# Requirement already satisfied: grpcio!=1.48.0,!=1.59.*,!=1.60.*,!=1.61.*,!=1.62.0,!=1.62.1,<1.66.0,<2,>=1.33.1 in /usr/local/lib/python3.12/dist-packages (from apache-beam[interactive]) (1.65.5)
# Requirement already satisfied: hdfs<3.0.0,>=2.1.0 in /usr/local/lib/python3.12/dist-packages (from apache-beam[interactive]) (2.7.3)
# Requirement already satisfied: httplib2<0.23.0,>=0.8 in /usr/local/lib/python3.12/dist-packages (from apache-beam[interactive]) (0.22.0)
# Requirement already satisfied: jsonschema<5.0.0,>=4.0.0 in /usr/local/lib/python3.12/dist-packages (from apache-beam[interactive]) (4.25.1)
# Requirement already satisfied: jsonpickle<4.0.0,>=3.0.0 in /usr/local/lib/python3.12/dist-packages (from apache-beam[interactive]) (3.4.2)
# Requirement already satisfied: numpy<2.3.0,>=1.14.3 in /usr/local/lib/python3.12/dist-packages (from apache-beam[interactive]) (2.0.2)
# Requirement already satisfied: objsize<0.8.0,>=0.6.1 in /usr/local/lib/python3.12/dist-packages (from apache-beam[interactive]) (0.7.1)
# Requirement already satisfied: packaging>=22.0 in /usr/local/lib/python3.12/dist-packages (from apache-beam[interactive]) (25.0)
# Requirement already satisfied: pymongo<5.0.0,>=3.8.0 in /usr/local/lib/python3.12/dist-packages (from apache-beam[interactive]) (4.15.3)
# Requirement already satisfied: proto-plus<2,>=1.7.1 in /usr/local/lib/python3.12/dist-packages (from apache-beam[interactive]) (1.26.1)
# Requirement already satisfied: protobuf!=4.0.*,!=4.21.*,!=4.22.0,!=4.23.*,!=4.24.*,<7.0.0.dev0,>=3.20.3 in /usr/local/lib/python3.12/dist-packages (from apache-beam[interactive]) (5.29.5)
# Requirement already satisfied: pydot<2,>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from apache-beam[interactive]) (1.4.2)
# Requirement already satisfied: python-dateutil<3,>=2.8.0 in /usr/local/lib/python3.12/dist-packages (from apache-beam[interactive]) (2.9.0.post0)
# Requirement already satisfied: pytz>=2018.3 in /usr/local/lib/python3.12/dist-packages (from apache-beam[interactive]) (2025.2)
# Requirement already satisfied: redis<6,>=5.0.0 in /usr/local/lib/python3.12/dist-packages (from apache-beam[interactive]) (5.3.1)
# Requirement already satisfied: regex>=2020.6.8 in /usr/local/lib/python3.12/dist-packages (from apache-beam[interactive]) (2024.11.6)
# Requirement already satisfied: requests<3.0.0,>=2.32.4 in /usr/local/lib/python3.12/dist-packages (from apache-beam[interactive]) (2.32.4)
# Requirement already satisfied: sortedcontainers>=2.4.0 in /usr/local/lib/python3.12/dist-packages (from apache-beam[interactive]) (2.4.0)
# Requirement already satisfied: typing-extensions>=3.7.0 in /usr/local/lib/python3.12/dist-packages (from apache-beam[interactive]) (4.15.0)
# Requirement already satisfied: zstandard<1,>=0.18.0 in /usr/local/lib/python3.12/dist-packages (from apache-beam[interactive]) (0.25.0)
# Requirement already satisfied: pyyaml<7.0.0,>=3.12 in /usr/local/lib/python3.12/dist-packages (from apache-beam[interactive]) (6.0.3)
# Requirement already satisfied: beartype<0.22.0,>=0.21.0 in /usr/local/lib/python3.12/dist-packages (from apache-beam[interactive]) (0.21.0)
# Requirement already satisfied: pyarrow<19.0.0,>=3.0.0 in /usr/local/lib/python3.12/dist-packages (from apache-beam[interactive]) (18.1.0)
# Requirement already satisfied: pyarrow-hotfix<1 in /usr/local/lib/python3.12/dist-packages (from apache-beam[interactive]) (0.7)
# Requirement already satisfied: facets-overview<2,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from apache-beam[interactive]) (1.1.1)
# Requirement already satisfied: google-cloud-dataproc<6,>=5.0.0 in /usr/local/lib/python3.12/dist-packages (from apache-beam[interactive]) (5.23.0)
# Requirement already satisfied: ipython<9,>=7 in /usr/local/lib/python3.12/dist-packages (from apache-beam[interactive]) (7.34.0)
# Requirement already satisfied: ipykernel<7,>=6 in /usr/local/lib/python3.12/dist-packages (from apache-beam[interactive]) (6.17.1)
# Requirement already satisfied: ipywidgets<9,>=8 in /usr/local/lib/python3.12/dist-packages (from apache-beam[interactive]) (8.1.7)
# Requirement already satisfied: jupyter-client!=6.1.13,<8.2.1,>=6.1.11 in /usr/local/lib/python3.12/dist-packages (from apache-beam[interactive]) (7.4.9)
# Requirement already satisfied: timeloop<2,>=1.0.2 in /usr/local/lib/python3.12/dist-packages (from apache-beam[interactive]) (1.0.2)
# Requirement already satisfied: nbformat<6,>=5.0.5 in /usr/local/lib/python3.12/dist-packages (from apache-beam[interactive]) (5.10.4)
# Requirement already satisfied: nbconvert<8,>=6.2.0 in /usr/local/lib/python3.12/dist-packages (from apache-beam[interactive]) (7.16.6)
# Requirement already satisfied: pandas!=1.5.0,!=1.5.1,<2.3,>=1.4.3 in /usr/local/lib/python3.12/dist-packages (from apache-beam[interactive]) (2.2.2)
# Requirement already satisfied: cffi>=1.12 in /usr/local/lib/python3.12/dist-packages (from cryptography<48.0.0,>=39.0.0->apache-beam[interactive]) (2.0.0)
# Requirement already satisfied: google-api-core!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1 in /usr/local/lib/python3.12/dist-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-cloud-dataproc<6,>=5.0.0->apache-beam[interactive]) (2.28.0)
# Requirement already satisfied: google-auth!=2.24.0,!=2.25.0,<3.0.0,>=2.14.1 in /usr/local/lib/python3.12/dist-packages (from google-cloud-dataproc<6,>=5.0.0->apache-beam[interactive]) (2.38.0)
# Requirement already satisfied: grpc-google-iam-v1<1.0.0,>=0.14.0 in /usr/local/lib/python3.12/dist-packages (from google-cloud-dataproc<6,>=5.0.0->apache-beam[interactive]) (0.14.3)
# Requirement already satisfied: docopt in /usr/local/lib/python3.12/dist-packages (from hdfs<3.0.0,>=2.1.0->apache-beam[interactive]) (0.6.2)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.12/dist-packages (from hdfs<3.0.0,>=2.1.0->apache-beam[interactive]) (1.17.0)
# Requirement already satisfied: pyparsing!=3.0.0,!=3.0.1,!=3.0.2,!=3.0.3,<4,>=2.4.2 in /usr/local/lib/python3.12/dist-packages (from httplib2<0.23.0,>=0.8->apache-beam[interactive]) (3.2.5)
# Requirement already satisfied: debugpy>=1.0 in /usr/local/lib/python3.12/dist-packages (from ipykernel<7,>=6->apache-beam[interactive]) (1.8.15)
# Requirement already satisfied: matplotlib-inline>=0.1 in /usr/local/lib/python3.12/dist-packages (from ipykernel<7,>=6->apache-beam[interactive]) (0.2.1)
# Requirement already satisfied: nest-asyncio in /usr/local/lib/python3.12/dist-packages (from ipykernel<7,>=6->apache-beam[interactive]) (1.6.0)
# Requirement already satisfied: psutil in /usr/local/lib/python3.12/dist-packages (from ipykernel<7,>=6->apache-beam[interactive]) (5.9.5)
# Requirement already satisfied: pyzmq>=17 in /usr/local/lib/python3.12/dist-packages (from ipykernel<7,>=6->apache-beam[interactive]) (26.2.1)
# Requirement already satisfied: tornado>=6.1 in /usr/local/lib/python3.12/dist-packages (from ipykernel<7,>=6->apache-beam[interactive]) (6.5.1)
# Requirement already satisfied: traitlets>=5.1.0 in /usr/local/lib/python3.12/dist-packages (from ipykernel<7,>=6->apache-beam[interactive]) (5.7.1)
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.12/dist-packages (from ipython<9,>=7->apache-beam[interactive]) (75.2.0)
# Requirement already satisfied: jedi>=0.16 in /usr/local/lib/python3.12/dist-packages (from ipython<9,>=7->apache-beam[interactive]) (0.19.2)
# Requirement already satisfied: decorator in /usr/local/lib/python3.12/dist-packages (from ipython<9,>=7->apache-beam[interactive]) (4.4.2)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.12/dist-packages (from ipython<9,>=7->apache-beam[interactive]) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from ipython<9,>=7->apache-beam[interactive]) (3.0.52)
# Requirement already satisfied: pygments in /usr/local/lib/python3.12/dist-packages (from ipython<9,>=7->apache-beam[interactive]) (2.19.2)
# Requirement already satisfied: backcall in /usr/local/lib/python3.12/dist-packages (from ipython<9,>=7->apache-beam[interactive]) (0.2.0)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.12/dist-packages (from ipython<9,>=7->apache-beam[interactive]) (4.9.0)
# Requirement already satisfied: comm>=0.1.3 in /usr/local/lib/python3.12/dist-packages (from ipywidgets<9,>=8->apache-beam[interactive]) (0.2.3)
# Requirement already satisfied: widgetsnbextension~=4.0.14 in /usr/local/lib/python3.12/dist-packages (from ipywidgets<9,>=8->apache-beam[interactive]) (4.0.14)
# Requirement already satisfied: jupyterlab_widgets~=3.0.15 in /usr/local/lib/python3.12/dist-packages (from ipywidgets<9,>=8->apache-beam[interactive]) (3.0.15)
# Requirement already satisfied: attrs>=22.2.0 in /usr/local/lib/python3.12/dist-packages (from jsonschema<5.0.0,>=4.0.0->apache-beam[interactive]) (25.4.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.12/dist-packages (from jsonschema<5.0.0,>=4.0.0->apache-beam[interactive]) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.12/dist-packages (from jsonschema<5.0.0,>=4.0.0->apache-beam[interactive]) (0.37.0)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.12/dist-packages (from jsonschema<5.0.0,>=4.0.0->apache-beam[interactive]) (0.28.0)
# Requirement already satisfied: entrypoints in /usr/local/lib/python3.12/dist-packages (from jupyter-client!=6.1.13,<8.2.1,>=6.1.11->apache-beam[interactive]) (0.4)
# Requirement already satisfied: jupyter-core>=4.9.2 in /usr/local/lib/python3.12/dist-packages (from jupyter-client!=6.1.13,<8.2.1,>=6.1.11->apache-beam[interactive]) (5.9.1)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.12/dist-packages (from nbconvert<8,>=6.2.0->apache-beam[interactive]) (4.13.5)
# Requirement already satisfied: bleach!=5.0.0 in /usr/local/lib/python3.12/dist-packages (from bleach[css]!=5.0.0->nbconvert<8,>=6.2.0->apache-beam[interactive]) (6.3.0)
# Requirement already satisfied: defusedxml in /usr/local/lib/python3.12/dist-packages (from nbconvert<8,>=6.2.0->apache-beam[interactive]) (0.7.1)
# Requirement already satisfied: jinja2>=3.0 in /usr/local/lib/python3.12/dist-packages (from nbconvert<8,>=6.2.0->apache-beam[interactive]) (3.1.6)
# Requirement already satisfied: jupyterlab-pygments in /usr/local/lib/python3.12/dist-packages (from nbconvert<8,>=6.2.0->apache-beam[interactive]) (0.3.0)
# Requirement already satisfied: markupsafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from nbconvert<8,>=6.2.0->apache-beam[interactive]) (3.0.3)
# Requirement already satisfied: mistune<4,>=2.0.3 in /usr/local/lib/python3.12/dist-packages (from nbconvert<8,>=6.2.0->apache-beam[interactive]) (3.1.4)
# Requirement already satisfied: nbclient>=0.5.0 in /usr/local/lib/python3.12/dist-packages (from nbconvert<8,>=6.2.0->apache-beam[interactive]) (0.10.2)
# Requirement already satisfied: pandocfilters>=1.4.1 in /usr/local/lib/python3.12/dist-packages (from nbconvert<8,>=6.2.0->apache-beam[interactive]) (1.5.1)
# Requirement already satisfied: fastjsonschema>=2.15 in /usr/local/lib/python3.12/dist-packages (from nbformat<6,>=5.0.5->apache-beam[interactive]) (2.21.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas!=1.5.0,!=1.5.1,<2.3,>=1.4.3->apache-beam[interactive]) (2025.2)
# Requirement already satisfied: dnspython<3.0.0,>=1.16.0 in /usr/local/lib/python3.12/dist-packages (from pymongo<5.0.0,>=3.8.0->apache-beam[interactive]) (2.8.0)
# Requirement already satisfied: PyJWT>=2.9.0 in /usr/local/lib/python3.12/dist-packages (from redis<6,>=5.0.0->apache-beam[interactive]) (2.10.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.32.4->apache-beam[interactive]) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.32.4->apache-beam[interactive]) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.32.4->apache-beam[interactive]) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.32.4->apache-beam[interactive]) (2025.10.5)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.12/dist-packages (from bleach!=5.0.0->bleach[css]!=5.0.0->nbconvert<8,>=6.2.0->apache-beam[interactive]) (0.5.1)
# Requirement already satisfied: tinycss2<1.5,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from bleach[css]!=5.0.0->nbconvert<8,>=6.2.0->apache-beam[interactive]) (1.4.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.12/dist-packages (from cffi>=1.12->cryptography<48.0.0,>=39.0.0->apache-beam[interactive]) (2.23)
# Requirement already satisfied: googleapis-common-protos<2.0.0,>=1.56.2 in /usr/local/lib/python3.12/dist-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-cloud-dataproc<6,>=5.0.0->apache-beam[interactive]) (1.71.0)
# Requirement already satisfied: grpcio-status<2.0.0,>=1.33.2 in /usr/local/lib/python3.12/dist-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-cloud-dataproc<6,>=5.0.0->apache-beam[interactive]) (1.65.5)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0,>=2.14.1->google-cloud-dataproc<6,>=5.0.0->apache-beam[interactive]) (5.5.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.12/dist-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0,>=2.14.1->google-cloud-dataproc<6,>=5.0.0->apache-beam[interactive]) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.12/dist-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0,>=2.14.1->google-cloud-dataproc<6,>=5.0.0->apache-beam[interactive]) (4.9.1)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /usr/local/lib/python3.12/dist-packages (from jedi>=0.16->ipython<9,>=7->apache-beam[interactive]) (0.8.5)
# Requirement already satisfied: platformdirs>=2.5 in /usr/local/lib/python3.12/dist-packages (from jupyter-core>=4.9.2->jupyter-client!=6.1.13,<8.2.1,>=6.1.11->apache-beam[interactive]) (4.5.0)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.12/dist-packages (from pexpect>4.3->ipython<9,>=7->apache-beam[interactive]) (0.7.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.12/dist-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython<9,>=7->apache-beam[interactive]) (0.2.14)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.12/dist-packages (from beautifulsoup4->nbconvert<8,>=6.2.0->apache-beam[interactive]) (2.8)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in /usr/local/lib/python3.12/dist-packages (from pyasn1-modules>=0.2.1->google-auth!=2.24.0,!=2.25.0,<3.0.0,>=2.14.1->google-cloud-dataproc<6,>=5.0.0->apache-beam[interactive]) (0.6.1)

# %%
import apache_beam as beam
print("Apache Beam Version:", beam.__version__)
# Out:
# Apache Beam Version: 2.69.0

# %%
# !pip install pandas scikit-learn apache-beam[gcp]
# Out:
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (2.2.2)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.12/dist-packages (1.6.1)
# Requirement already satisfied: apache-beam[gcp] in /usr/local/lib/python3.12/dist-packages (2.69.0)
# Requirement already satisfied: numpy>=1.26.0 in /usr/local/lib/python3.12/dist-packages (from pandas) (2.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn) (1.16.3)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn) (1.5.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: crcmod<2.0,>=1.7 in /usr/local/lib/python3.12/dist-packages (from apache-beam[gcp]) (1.7)
# Requirement already satisfied: cryptography<48.0.0,>=39.0.0 in /usr/local/lib/python3.12/dist-packages (from apache-beam[gcp]) (43.0.3)
# Requirement already satisfied: orjson<4,>=3.9.7 in /usr/local/lib/python3.12/dist-packages (from apache-beam[gcp]) (3.11.4)
# Requirement already satisfied: fastavro<2,>=0.23.6 in /usr/local/lib/python3.12/dist-packages (from apache-beam[gcp]) (1.12.1)
# Requirement already satisfied: fasteners<1.0,>=0.3 in /usr/local/lib/python3.12/dist-packages (from apache-beam[gcp]) (0.20)
# Requirement already satisfied: grpcio!=1.48.0,!=1.59.*,!=1.60.*,!=1.61.*,!=1.62.0,!=1.62.1,<1.66.0,<2,>=1.33.1 in /usr/local/lib/python3.12/dist-packages (from apache-beam[gcp]) (1.65.5)
# Requirement already satisfied: hdfs<3.0.0,>=2.1.0 in /usr/local/lib/python3.12/dist-packages (from apache-beam[gcp]) (2.7.3)
# Requirement already satisfied: httplib2<0.23.0,>=0.8 in /usr/local/lib/python3.12/dist-packages (from apache-beam[gcp]) (0.22.0)
# Requirement already satisfied: jsonschema<5.0.0,>=4.0.0 in /usr/local/lib/python3.12/dist-packages (from apache-beam[gcp]) (4.25.1)
# Requirement already satisfied: jsonpickle<4.0.0,>=3.0.0 in /usr/local/lib/python3.12/dist-packages (from apache-beam[gcp]) (3.4.2)
# Requirement already satisfied: objsize<0.8.0,>=0.6.1 in /usr/local/lib/python3.12/dist-packages (from apache-beam[gcp]) (0.7.1)
# Requirement already satisfied: packaging>=22.0 in /usr/local/lib/python3.12/dist-packages (from apache-beam[gcp]) (25.0)
# Requirement already satisfied: pymongo<5.0.0,>=3.8.0 in /usr/local/lib/python3.12/dist-packages (from apache-beam[gcp]) (4.15.3)
# Requirement already satisfied: proto-plus<2,>=1.7.1 in /usr/local/lib/python3.12/dist-packages (from apache-beam[gcp]) (1.26.1)
# Requirement already satisfied: protobuf!=4.0.*,!=4.21.*,!=4.22.0,!=4.23.*,!=4.24.*,<7.0.0.dev0,>=3.20.3 in /usr/local/lib/python3.12/dist-packages (from apache-beam[gcp]) (5.29.5)
# Requirement already satisfied: pydot<2,>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from apache-beam[gcp]) (1.4.2)
# Requirement already satisfied: redis<6,>=5.0.0 in /usr/local/lib/python3.12/dist-packages (from apache-beam[gcp]) (5.3.1)
# Requirement already satisfied: regex>=2020.6.8 in /usr/local/lib/python3.12/dist-packages (from apache-beam[gcp]) (2024.11.6)
# Requirement already satisfied: requests<3.0.0,>=2.32.4 in /usr/local/lib/python3.12/dist-packages (from apache-beam[gcp]) (2.32.4)
# Requirement already satisfied: sortedcontainers>=2.4.0 in /usr/local/lib/python3.12/dist-packages (from apache-beam[gcp]) (2.4.0)
# Requirement already satisfied: typing-extensions>=3.7.0 in /usr/local/lib/python3.12/dist-packages (from apache-beam[gcp]) (4.15.0)
# Requirement already satisfied: zstandard<1,>=0.18.0 in /usr/local/lib/python3.12/dist-packages (from apache-beam[gcp]) (0.25.0)
# Requirement already satisfied: pyyaml<7.0.0,>=3.12 in /usr/local/lib/python3.12/dist-packages (from apache-beam[gcp]) (6.0.3)
# Requirement already satisfied: beartype<0.22.0,>=0.21.0 in /usr/local/lib/python3.12/dist-packages (from apache-beam[gcp]) (0.21.0)
# Requirement already satisfied: pyarrow<19.0.0,>=3.0.0 in /usr/local/lib/python3.12/dist-packages (from apache-beam[gcp]) (18.1.0)
# Requirement already satisfied: pyarrow-hotfix<1 in /usr/local/lib/python3.12/dist-packages (from apache-beam[gcp]) (0.7)
# Requirement already satisfied: cachetools<7,>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from apache-beam[gcp]) (5.5.2)
# Requirement already satisfied: google-api-core<3,>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from apache-beam[gcp]) (2.28.0)
# Requirement already satisfied: google-apitools<0.5.32,>=0.5.31 in /usr/local/lib/python3.12/dist-packages (from apache-beam[gcp]) (0.5.31)
# Requirement already satisfied: google-auth<3,>=1.18.0 in /usr/local/lib/python3.12/dist-packages (from apache-beam[gcp]) (2.38.0)
# Requirement already satisfied: google-auth-httplib2<0.3.0,>=0.1.0 in /usr/local/lib/python3.12/dist-packages (from apache-beam[gcp]) (0.2.0)
# Requirement already satisfied: google-cloud-datastore<3,>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from apache-beam[gcp]) (2.21.0)
# Requirement already satisfied: google-cloud-pubsub<3,>=2.1.0 in /usr/local/lib/python3.12/dist-packages (from apache-beam[gcp]) (2.32.0)
# Requirement already satisfied: google-cloud-pubsublite<2,>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from apache-beam[gcp]) (1.12.0)
# Requirement already satisfied: google-cloud-storage<3,>=2.18.2 in /usr/local/lib/python3.12/dist-packages (from apache-beam[gcp]) (2.19.0)
# Requirement already satisfied: google-cloud-bigquery<4,>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from apache-beam[gcp]) (3.38.0)
# Requirement already satisfied: google-cloud-bigquery-storage<3,>=2.6.3 in /usr/local/lib/python3.12/dist-packages (from apache-beam[gcp]) (2.34.0)
# Requirement already satisfied: google-cloud-core<3,>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from apache-beam[gcp]) (2.4.3)
# Requirement already satisfied: google-cloud-bigtable<3,>=2.19.0 in /usr/local/lib/python3.12/dist-packages (from apache-beam[gcp]) (2.34.0)
# Requirement already satisfied: google-cloud-spanner<4,>=3.0.0 in /usr/local/lib/python3.12/dist-packages (from apache-beam[gcp]) (3.59.0)
# Requirement already satisfied: google-cloud-dlp<4,>=3.0.0 in /usr/local/lib/python3.12/dist-packages (from apache-beam[gcp]) (3.33.0)
# Requirement already satisfied: google-cloud-language<3,>=2.0 in /usr/local/lib/python3.12/dist-packages (from apache-beam[gcp]) (2.18.0)
# Requirement already satisfied: google-cloud-secret-manager<3,>=2.0 in /usr/local/lib/python3.12/dist-packages (from apache-beam[gcp]) (2.25.0)
# Requirement already satisfied: google-cloud-videointelligence<3,>=2.0 in /usr/local/lib/python3.12/dist-packages (from apache-beam[gcp]) (2.17.0)
# Requirement already satisfied: google-cloud-vision<4,>=2 in /usr/local/lib/python3.12/dist-packages (from apache-beam[gcp]) (3.11.0)
# Requirement already satisfied: google-cloud-recommendations-ai<0.11.0,>=0.1.0 in /usr/local/lib/python3.12/dist-packages (from apache-beam[gcp]) (0.10.18)
# Requirement already satisfied: google-cloud-aiplatform<2.0,>=1.26.0 in /usr/local/lib/python3.12/dist-packages (from apache-beam[gcp]) (1.122.0)
# Requirement already satisfied: cloud-sql-python-connector<2.0.0,>=1.18.2 in /usr/local/lib/python3.12/dist-packages (from apache-beam[gcp]) (1.18.5)
# Requirement already satisfied: python-tds>=1.16.1 in /usr/local/lib/python3.12/dist-packages (from apache-beam[gcp]) (1.17.1)
# Requirement already satisfied: pg8000>=1.31.1 in /usr/local/lib/python3.12/dist-packages (from apache-beam[gcp]) (1.31.5)
# Requirement already satisfied: PyMySQL>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from apache-beam[gcp]) (1.1.2)
# Requirement already satisfied: keyrings.google-artifactregistry-auth in /usr/local/lib/python3.12/dist-packages (from apache-beam[gcp]) (1.1.2)
# Requirement already satisfied: aiofiles in /usr/local/lib/python3.12/dist-packages (from cloud-sql-python-connector<2.0.0,>=1.18.2->apache-beam[gcp]) (24.1.0)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.12/dist-packages (from cloud-sql-python-connector<2.0.0,>=1.18.2->apache-beam[gcp]) (3.13.1)
# Requirement already satisfied: dnspython>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from cloud-sql-python-connector<2.0.0,>=1.18.2->apache-beam[gcp]) (2.8.0)
# Requirement already satisfied: cffi>=1.12 in /usr/local/lib/python3.12/dist-packages (from cryptography<48.0.0,>=39.0.0->apache-beam[gcp]) (2.0.0)
# Requirement already satisfied: googleapis-common-protos<2.0.0,>=1.56.2 in /usr/local/lib/python3.12/dist-packages (from google-api-core<3,>=2.0.0->apache-beam[gcp]) (1.71.0)
# Requirement already satisfied: oauth2client>=1.4.12 in /usr/local/lib/python3.12/dist-packages (from google-apitools<0.5.32,>=0.5.31->apache-beam[gcp]) (4.1.3)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.12/dist-packages (from google-apitools<0.5.32,>=0.5.31->apache-beam[gcp]) (1.17.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.12/dist-packages (from google-auth<3,>=1.18.0->apache-beam[gcp]) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.12/dist-packages (from google-auth<3,>=1.18.0->apache-beam[gcp]) (4.9.1)
# Requirement already satisfied: google-cloud-resource-manager<3.0.0,>=1.3.3 in /usr/local/lib/python3.12/dist-packages (from google-cloud-aiplatform<2.0,>=1.26.0->apache-beam[gcp]) (1.15.0)
# Requirement already satisfied: shapely<3.0.0 in /usr/local/lib/python3.12/dist-packages (from google-cloud-aiplatform<2.0,>=1.26.0->apache-beam[gcp]) (2.1.2)
# Requirement already satisfied: google-genai<2.0.0,>=1.37.0 in /usr/local/lib/python3.12/dist-packages (from google-cloud-aiplatform<2.0,>=1.26.0->apache-beam[gcp]) (1.46.0)
# Requirement already satisfied: pydantic<3 in /usr/local/lib/python3.12/dist-packages (from google-cloud-aiplatform<2.0,>=1.26.0->apache-beam[gcp]) (2.11.10)
# Requirement already satisfied: docstring_parser<1 in /usr/local/lib/python3.12/dist-packages (from google-cloud-aiplatform<2.0,>=1.26.0->apache-beam[gcp]) (0.17.0)
# Requirement already satisfied: google-resumable-media<3.0.0,>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from google-cloud-bigquery<4,>=2.0.0->apache-beam[gcp]) (2.7.2)
# Requirement already satisfied: grpc-google-iam-v1<1.0.0,>=0.12.4 in /usr/local/lib/python3.12/dist-packages (from google-cloud-bigtable<3,>=2.19.0->apache-beam[gcp]) (0.14.3)
# Requirement already satisfied: google-crc32c<2.0.0dev,>=1.5.0 in /usr/local/lib/python3.12/dist-packages (from google-cloud-bigtable<3,>=2.19.0->apache-beam[gcp]) (1.7.1)
# Requirement already satisfied: grpcio-status>=1.33.2 in /usr/local/lib/python3.12/dist-packages (from google-cloud-pubsub<3,>=2.1.0->apache-beam[gcp]) (1.65.5)
# Requirement already satisfied: opentelemetry-api>=1.27.0 in /usr/local/lib/python3.12/dist-packages (from google-cloud-pubsub<3,>=2.1.0->apache-beam[gcp]) (1.37.0)
# Requirement already satisfied: opentelemetry-sdk>=1.27.0 in /usr/local/lib/python3.12/dist-packages (from google-cloud-pubsub<3,>=2.1.0->apache-beam[gcp]) (1.37.0)
# Requirement already satisfied: overrides<8.0.0,>=6.0.1 in /usr/local/lib/python3.12/dist-packages (from google-cloud-pubsublite<2,>=1.2.0->apache-beam[gcp]) (7.7.0)
# Requirement already satisfied: sqlparse>=0.4.4 in /usr/local/lib/python3.12/dist-packages (from google-cloud-spanner<4,>=3.0.0->apache-beam[gcp]) (0.5.3)
# Requirement already satisfied: grpc-interceptor>=0.15.4 in /usr/local/lib/python3.12/dist-packages (from google-cloud-spanner<4,>=3.0.0->apache-beam[gcp]) (0.15.4)
# Requirement already satisfied: docopt in /usr/local/lib/python3.12/dist-packages (from hdfs<3.0.0,>=2.1.0->apache-beam[gcp]) (0.6.2)
# Requirement already satisfied: pyparsing!=3.0.0,!=3.0.1,!=3.0.2,!=3.0.3,<4,>=2.4.2 in /usr/local/lib/python3.12/dist-packages (from httplib2<0.23.0,>=0.8->apache-beam[gcp]) (3.2.5)
# Requirement already satisfied: attrs>=22.2.0 in /usr/local/lib/python3.12/dist-packages (from jsonschema<5.0.0,>=4.0.0->apache-beam[gcp]) (25.4.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.12/dist-packages (from jsonschema<5.0.0,>=4.0.0->apache-beam[gcp]) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.12/dist-packages (from jsonschema<5.0.0,>=4.0.0->apache-beam[gcp]) (0.37.0)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.12/dist-packages (from jsonschema<5.0.0,>=4.0.0->apache-beam[gcp]) (0.28.0)
# Requirement already satisfied: scramp>=1.4.5 in /usr/local/lib/python3.12/dist-packages (from pg8000>=1.31.1->apache-beam[gcp]) (1.4.6)
# Requirement already satisfied: PyJWT>=2.9.0 in /usr/local/lib/python3.12/dist-packages (from redis<6,>=5.0.0->apache-beam[gcp]) (2.10.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.32.4->apache-beam[gcp]) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.32.4->apache-beam[gcp]) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.32.4->apache-beam[gcp]) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.32.4->apache-beam[gcp]) (2025.10.5)
# Requirement already satisfied: keyring in /usr/local/lib/python3.12/dist-packages (from keyrings.google-artifactregistry-auth->apache-beam[gcp]) (25.6.0)
# Requirement already satisfied: pluggy in /usr/local/lib/python3.12/dist-packages (from keyrings.google-artifactregistry-auth->apache-beam[gcp]) (1.6.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.12/dist-packages (from cffi>=1.12->cryptography<48.0.0,>=39.0.0->apache-beam[gcp]) (2.23)
# Requirement already satisfied: anyio<5.0.0,>=4.8.0 in /usr/local/lib/python3.12/dist-packages (from google-genai<2.0.0,>=1.37.0->google-cloud-aiplatform<2.0,>=1.26.0->apache-beam[gcp]) (4.11.0)
# Requirement already satisfied: httpx<1.0.0,>=0.28.1 in /usr/local/lib/python3.12/dist-packages (from google-genai<2.0.0,>=1.37.0->google-cloud-aiplatform<2.0,>=1.26.0->apache-beam[gcp]) (0.28.1)
# Requirement already satisfied: tenacity<9.2.0,>=8.2.3 in /usr/local/lib/python3.12/dist-packages (from google-genai<2.0.0,>=1.37.0->google-cloud-aiplatform<2.0,>=1.26.0->apache-beam[gcp]) (8.5.0)
# Requirement already satisfied: websockets<15.1.0,>=13.0.0 in /usr/local/lib/python3.12/dist-packages (from google-genai<2.0.0,>=1.37.0->google-cloud-aiplatform<2.0,>=1.26.0->apache-beam[gcp]) (15.0.1)
# Requirement already satisfied: pyasn1>=0.1.7 in /usr/local/lib/python3.12/dist-packages (from oauth2client>=1.4.12->google-apitools<0.5.32,>=0.5.31->apache-beam[gcp]) (0.6.1)
# Requirement already satisfied: importlib-metadata<8.8.0,>=6.0 in /usr/local/lib/python3.12/dist-packages (from opentelemetry-api>=1.27.0->google-cloud-pubsub<3,>=2.1.0->apache-beam[gcp]) (8.7.0)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.58b0 in /usr/local/lib/python3.12/dist-packages (from opentelemetry-sdk>=1.27.0->google-cloud-pubsub<3,>=2.1.0->apache-beam[gcp]) (0.58b0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic<3->google-cloud-aiplatform<2.0,>=1.26.0->apache-beam[gcp]) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /usr/local/lib/python3.12/dist-packages (from pydantic<3->google-cloud-aiplatform<2.0,>=1.26.0->apache-beam[gcp]) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.12/dist-packages (from pydantic<3->google-cloud-aiplatform<2.0,>=1.26.0->apache-beam[gcp]) (0.4.2)
# Requirement already satisfied: asn1crypto>=1.5.1 in /usr/local/lib/python3.12/dist-packages (from scramp>=1.4.5->pg8000>=1.31.1->apache-beam[gcp]) (1.5.1)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp->cloud-sql-python-connector<2.0.0,>=1.18.2->apache-beam[gcp]) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp->cloud-sql-python-connector<2.0.0,>=1.18.2->apache-beam[gcp]) (1.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from aiohttp->cloud-sql-python-connector<2.0.0,>=1.18.2->apache-beam[gcp]) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.12/dist-packages (from aiohttp->cloud-sql-python-connector<2.0.0,>=1.18.2->apache-beam[gcp]) (6.7.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp->cloud-sql-python-connector<2.0.0,>=1.18.2->apache-beam[gcp]) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp->cloud-sql-python-connector<2.0.0,>=1.18.2->apache-beam[gcp]) (1.22.0)
# Requirement already satisfied: SecretStorage>=3.2 in /usr/local/lib/python3.12/dist-packages (from keyring->keyrings.google-artifactregistry-auth->apache-beam[gcp]) (3.4.0)
# Requirement already satisfied: jeepney>=0.4.2 in /usr/local/lib/python3.12/dist-packages (from keyring->keyrings.google-artifactregistry-auth->apache-beam[gcp]) (0.9.0)
# Requirement already satisfied: jaraco.classes in /usr/local/lib/python3.12/dist-packages (from keyring->keyrings.google-artifactregistry-auth->apache-beam[gcp]) (3.4.0)
# Requirement already satisfied: jaraco.functools in /usr/local/lib/python3.12/dist-packages (from keyring->keyrings.google-artifactregistry-auth->apache-beam[gcp]) (4.3.0)
# Requirement already satisfied: jaraco.context in /usr/local/lib/python3.12/dist-packages (from keyring->keyrings.google-artifactregistry-auth->apache-beam[gcp]) (6.0.1)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.12/dist-packages (from anyio<5.0.0,>=4.8.0->google-genai<2.0.0,>=1.37.0->google-cloud-aiplatform<2.0,>=1.26.0->apache-beam[gcp]) (1.3.1)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1.0.0,>=0.28.1->google-genai<2.0.0,>=1.37.0->google-cloud-aiplatform<2.0,>=1.26.0->apache-beam[gcp]) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1.0.0,>=0.28.1->google-genai<2.0.0,>=1.37.0->google-cloud-aiplatform<2.0,>=1.26.0->apache-beam[gcp]) (0.16.0)
# Requirement already satisfied: zipp>=3.20 in /usr/local/lib/python3.12/dist-packages (from importlib-metadata<8.8.0,>=6.0->opentelemetry-api>=1.27.0->google-cloud-pubsub<3,>=2.1.0->apache-beam[gcp]) (3.23.0)
# Requirement already satisfied: more-itertools in /usr/local/lib/python3.12/dist-packages (from jaraco.classes->keyring->keyrings.google-artifactregistry-auth->apache-beam[gcp]) (10.8.0)

# %%
import pandas as pd
import sklearn
print("Pandas Version:", pd.__version__)
print("Scikit-learn Version:", sklearn.__version__)
# Out:
# Pandas Version: 2.2.2
# Scikit-learn Version: 1.6.1

# %%
# !pip install apache-beam[ml] scikit-learn pandas

import apache_beam as beam
import pandas as pd
import sklearn

print("Apache Beam Version:", beam.__version__)
print("Pandas Version:", pd.__version__)
print("Scikit-learn Version:", sklearn.__version__)
# Out:
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.12/dist-packages (1.6.1)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (2.2.2)
# Requirement already satisfied: apache-beam[ml] in /usr/local/lib/python3.12/dist-packages (2.69.0)
# WARNING: apache-beam 2.69.0 does not provide the extra 'ml'
# Requirement already satisfied: crcmod<2.0,>=1.7 in /usr/local/lib/python3.12/dist-packages (from apache-beam[ml]) (1.7)
# Requirement already satisfied: cryptography<48.0.0,>=39.0.0 in /usr/local/lib/python3.12/dist-packages (from apache-beam[ml]) (43.0.3)
# Requirement already satisfied: orjson<4,>=3.9.7 in /usr/local/lib/python3.12/dist-packages (from apache-beam[ml]) (3.11.4)
# Requirement already satisfied: fastavro<2,>=0.23.6 in /usr/local/lib/python3.12/dist-packages (from apache-beam[ml]) (1.12.1)
# Requirement already satisfied: fasteners<1.0,>=0.3 in /usr/local/lib/python3.12/dist-packages (from apache-beam[ml]) (0.20)
# Requirement already satisfied: grpcio!=1.48.0,!=1.59.*,!=1.60.*,!=1.61.*,!=1.62.0,!=1.62.1,<1.66.0,<2,>=1.33.1 in /usr/local/lib/python3.12/dist-packages (from apache-beam[ml]) (1.65.5)
# Requirement already satisfied: hdfs<3.0.0,>=2.1.0 in /usr/local/lib/python3.12/dist-packages (from apache-beam[ml]) (2.7.3)
# Requirement already satisfied: httplib2<0.23.0,>=0.8 in /usr/local/lib/python3.12/dist-packages (from apache-beam[ml]) (0.22.0)
# Requirement already satisfied: jsonschema<5.0.0,>=4.0.0 in /usr/local/lib/python3.12/dist-packages (from apache-beam[ml]) (4.25.1)
# Requirement already satisfied: jsonpickle<4.0.0,>=3.0.0 in /usr/local/lib/python3.12/dist-packages (from apache-beam[ml]) (3.4.2)
# Requirement already satisfied: numpy<2.3.0,>=1.14.3 in /usr/local/lib/python3.12/dist-packages (from apache-beam[ml]) (2.0.2)
# Requirement already satisfied: objsize<0.8.0,>=0.6.1 in /usr/local/lib/python3.12/dist-packages (from apache-beam[ml]) (0.7.1)
# Requirement already satisfied: packaging>=22.0 in /usr/local/lib/python3.12/dist-packages (from apache-beam[ml]) (25.0)
# Requirement already satisfied: pymongo<5.0.0,>=3.8.0 in /usr/local/lib/python3.12/dist-packages (from apache-beam[ml]) (4.15.3)
# Requirement already satisfied: proto-plus<2,>=1.7.1 in /usr/local/lib/python3.12/dist-packages (from apache-beam[ml]) (1.26.1)
# Requirement already satisfied: protobuf!=4.0.*,!=4.21.*,!=4.22.0,!=4.23.*,!=4.24.*,<7.0.0.dev0,>=3.20.3 in /usr/local/lib/python3.12/dist-packages (from apache-beam[ml]) (5.29.5)
# Requirement already satisfied: pydot<2,>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from apache-beam[ml]) (1.4.2)
# Requirement already satisfied: python-dateutil<3,>=2.8.0 in /usr/local/lib/python3.12/dist-packages (from apache-beam[ml]) (2.9.0.post0)
# Requirement already satisfied: pytz>=2018.3 in /usr/local/lib/python3.12/dist-packages (from apache-beam[ml]) (2025.2)
# Requirement already satisfied: redis<6,>=5.0.0 in /usr/local/lib/python3.12/dist-packages (from apache-beam[ml]) (5.3.1)
# Requirement already satisfied: regex>=2020.6.8 in /usr/local/lib/python3.12/dist-packages (from apache-beam[ml]) (2024.11.6)
# Requirement already satisfied: requests<3.0.0,>=2.32.4 in /usr/local/lib/python3.12/dist-packages (from apache-beam[ml]) (2.32.4)
# Requirement already satisfied: sortedcontainers>=2.4.0 in /usr/local/lib/python3.12/dist-packages (from apache-beam[ml]) (2.4.0)
# Requirement already satisfied: typing-extensions>=3.7.0 in /usr/local/lib/python3.12/dist-packages (from apache-beam[ml]) (4.15.0)
# Requirement already satisfied: zstandard<1,>=0.18.0 in /usr/local/lib/python3.12/dist-packages (from apache-beam[ml]) (0.25.0)
# Requirement already satisfied: pyyaml<7.0.0,>=3.12 in /usr/local/lib/python3.12/dist-packages (from apache-beam[ml]) (6.0.3)
# Requirement already satisfied: beartype<0.22.0,>=0.21.0 in /usr/local/lib/python3.12/dist-packages (from apache-beam[ml]) (0.21.0)
# Requirement already satisfied: pyarrow<19.0.0,>=3.0.0 in /usr/local/lib/python3.12/dist-packages (from apache-beam[ml]) (18.1.0)
# Requirement already satisfied: pyarrow-hotfix<1 in /usr/local/lib/python3.12/dist-packages (from apache-beam[ml]) (0.7)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn) (1.16.3)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn) (1.5.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: cffi>=1.12 in /usr/local/lib/python3.12/dist-packages (from cryptography<48.0.0,>=39.0.0->apache-beam[ml]) (2.0.0)
# Requirement already satisfied: docopt in /usr/local/lib/python3.12/dist-packages (from hdfs<3.0.0,>=2.1.0->apache-beam[ml]) (0.6.2)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.12/dist-packages (from hdfs<3.0.0,>=2.1.0->apache-beam[ml]) (1.17.0)
# Requirement already satisfied: pyparsing!=3.0.0,!=3.0.1,!=3.0.2,!=3.0.3,<4,>=2.4.2 in /usr/local/lib/python3.12/dist-packages (from httplib2<0.23.0,>=0.8->apache-beam[ml]) (3.2.5)
# Requirement already satisfied: attrs>=22.2.0 in /usr/local/lib/python3.12/dist-packages (from jsonschema<5.0.0,>=4.0.0->apache-beam[ml]) (25.4.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.12/dist-packages (from jsonschema<5.0.0,>=4.0.0->apache-beam[ml]) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.12/dist-packages (from jsonschema<5.0.0,>=4.0.0->apache-beam[ml]) (0.37.0)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.12/dist-packages (from jsonschema<5.0.0,>=4.0.0->apache-beam[ml]) (0.28.0)
# Requirement already satisfied: dnspython<3.0.0,>=1.16.0 in /usr/local/lib/python3.12/dist-packages (from pymongo<5.0.0,>=3.8.0->apache-beam[ml]) (2.8.0)
# Requirement already satisfied: PyJWT>=2.9.0 in /usr/local/lib/python3.12/dist-packages (from redis<6,>=5.0.0->apache-beam[ml]) (2.10.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.32.4->apache-beam[ml]) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.32.4->apache-beam[ml]) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.32.4->apache-beam[ml]) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.32.4->apache-beam[ml]) (2025.10.5)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.12/dist-packages (from cffi>=1.12->cryptography<48.0.0,>=39.0.0->apache-beam[ml]) (2.23)
# Apache Beam Version: 2.69.0
# Pandas Version: 2.2.2
# Scikit-learn Version: 1.6.1

# %%
from apache_beam.runners.interactive import interactive_runner
from apache_beam.options.pipeline_options import PipelineOptions

print(" Apache Beam interactive mode is ready.")
# Out:
#  Apache Beam interactive mode is ready.

# %% [markdown]
# ## Map & Filter Transform
# This pipeline multiplies each number by 2 and filters values greater than 10.

# %%
pipeline = beam.Pipeline(options=PipelineOptions())

input_data = [1, 2, 3, 4, 5, 6, 7, 8, 9]

output = (
    pipeline
    | "Read Input Data" >> beam.Create(input_data)     # Pipeline IO
    | "Multiply by 2 (Map)" >> beam.Map(lambda x: x * 2)
    | "Filter > 10" >> beam.Filter(lambda x: x > 10)
)

pipeline_result = pipeline.run()
pipeline_result.wait_until_finish()

print("✅ Basic pipeline executed")
# Out:
# WARNING:apache_beam.options.pipeline_options:Discarding unparseable args: ['-f', '/root/.local/share/jupyter/runtime/kernel-35863f58-de45-466a-9b62-3589ed48e16b.json']
# WARNING:apache_beam.options.pipeline_options:Unparseable argument: -f
# WARNING:apache_beam.options.pipeline_options:Unparseable argument: /root/.local/share/jupyter/runtime/kernel-35863f58-de45-466a-9b62-3589ed48e16b.json
# WARNING:apache_beam.options.pipeline_options:Discarding flag -f, single dash flags are not allowed.
# WARNING:apache_beam.options.pipeline_options:Discarding unparseable args: ['-f', '/root/.local/share/jupyter/runtime/kernel-35863f58-de45-466a-9b62-3589ed48e16b.json']
# WARNING:apache_beam.options.pipeline_options:Discarding unparseable args: ['-f', '/root/.local/share/jupyter/runtime/kernel-35863f58-de45-466a-9b62-3589ed48e16b.json']
# ✅ Basic pipeline executed

# %%
class SquareFn(beam.DoFn):
    def process(self, element):
        yield element * element

with beam.Pipeline() as pipeline:
    (pipeline
     | "Create Numbers" >> beam.Create([1, 2, 3, 4, 5])
     | "Apply ParDo" >> beam.ParDo(SquareFn())
     | "Print Results" >> beam.Map(print)
    )
# Out:
# 1
# 4
# 9
# 16
# 25

# %%
class MultiplyAndFilter(beam.PTransform):
    def expand(self, pcoll):
        return (
            pcoll
            | "Multiply by 3" >> beam.Map(lambda x: x * 3)
            | "Filter > 15" >> beam.Filter(lambda x: x > 15)
        )

with beam.Pipeline() as pipeline:
    (pipeline
     | "Start Data" >> beam.Create([1, 5, 7, 10])
     | "Composite Transform" >> MultiplyAndFilter()
     | "Print Output" >> beam.Map(print)
    )
# Out:
# 21
# 30

# %%
import apache_beam as beam
from apache_beam.transforms.window import FixedWindows
from datetime import datetime
import time

# ✅ Function to add timestamp to elements
def add_timestamp(x):
    return beam.window.TimestampedValue(x, time.time())

with beam.Pipeline() as pipeline:
    (
        pipeline
        | "Create Stream Data" >> beam.Create([10, 20, 30, 40, 50])
        | "Add Timestamp" >> beam.Map(add_timestamp)
        | "Apply 10-second Window" >> beam.WindowInto(FixedWindows(10))
        | "Print Per Window" >> beam.Map(lambda x: print("Windowed:", x))
    )
# Out:
# Windowed: 10
# Windowed: 20
# Windowed: 30
# Windowed: 40
# Windowed: 50

# %%
def partition_numbers(element, num_partitions):
    return 0 if element % 2 == 0 else 1   # 0 → even, 1 → odd

with beam.Pipeline() as pipeline:
    partitions = (
        pipeline
        | "Create Numbers" >> beam.Create([10, 15, 20, 25, 30, 35])
        | "Partition Data" >> beam.Partition(partition_numbers, 2)
    )


    even = partitions[0] | "Even Numbers" >> beam.Map(lambda x: print("Even:", x))
    odd = partitions[1] | "Odd Numbers" >> beam.Map(lambda x: print("Odd:", x))
# Out:
# Even: 10
# Odd: 15
# Even: 20
# Odd: 25
# Even: 30
# Odd: 35

# %%
import apache_beam as beam
import pandas as pd

data = {
    'name': ['Alice', 'Bob', 'Charlie', 'David', 'Eve'],
    'score': [85, 42, 77, 90, 56]
}
df = pd.DataFrame(data)
df.to_csv('input_data.csv', index=False)


with beam.Pipeline() as pipeline:
    (
        pipeline
        | "Read CSV Lines" >> beam.io.ReadFromText('input_data.csv', skip_header_lines=1)
        | "Parse CSV" >> beam.Map(lambda line: line.split(','))
        | "Filter Scores > 60" >> beam.Filter(lambda x: int(x[1]) > 60)
        | "Format Output" >> beam.Map(lambda x: f"{x[0]} has score {x[1]}")
        | "Write Output" >> beam.io.WriteToText('output_results', file_name_suffix=".txt")
    )

print("✅ Beam I/O Completed — check 'output_results.txt'")
# Out:
# ✅ Beam I/O Completed — check 'output_results.txt'

# %%
import apache_beam as beam
import numpy as np
from sklearn.linear_model import LinearRegression

# ✅ Train model
X = np.array([[1], [2], [3], [4], [5]])
y = np.array([2, 4, 6, 8, 10])
model = LinearRegression().fit(X, y)

# ✅ Custom ParDo for prediction
class PredictDoFn(beam.DoFn):
    def process(self, element):
        prediction = model.predict([[element]])[0]
        yield f"Input: {element} → Predicted: {prediction}"

# ✅ Run Beam pipeline
with beam.Pipeline() as pipeline:
    (
        pipeline
        | "Create Input Numbers" >> beam.Create([6, 7, 8, 9])
        | "Predict Using Linear Model" >> beam.ParDo(PredictDoFn())
        | "Print Results" >> beam.Map(print)
    )
# Out:
# Input: 6 → Predicted: 12.0
# Input: 7 → Predicted: 14.0
# Input: 8 → Predicted: 16.0
# Input: 9 → Predicted: 18.0

# %% [markdown]
# +-------------------------+
# |      Input Source       |
# |  (CSV / List / Stream)  |
# +-----------+-------------+
#             |
#             v
# +-------------------------+
# |       Transform          |
# |  - Map / Filter / ParDo  |
# |  - Composite / Windowing |
# +-----------+-------------+
#             |
#             v
# +-------------------------+
# |   Partition / ML Model   |
# |  (RunInference)          |
# +-----------+-------------+
#             |
#             v
# +-------------------------+
# |       Output Sink        |
# |  (Text / CSV / Console)  |
# +-------------------------+

# %% [markdown]
# ### Conclusion
# This notebook demonstrates all required Apache Beam concepts:
# - Map & Filter
# - ParDo (custom DoFn)
# - Composite Transform
# - Partition
# - Windowing
# - Pipeline I/O (read/write)
# - Extra credit: ML prediction inside Beam pipeline
#
# All pipelines executed successfully in Google Colab.
